# %%
import numpy as np
from EOS import make_adiabat
from analyse import get_snapshot_data, M_earth, R_earth
import matplotlib.pyplot as plt

# %%
n = 0
file_path = '/home/pt426/Impacts/impact-1/sub_neptune_impact'
R_surface = 2.1

# %%
pos, m, id, rho, T, P, S, u, mat_id, vel = get_snapshot_data(n, file_path)

x, y, z = pos[:, 0], pos[:, 1], pos[:, 2]
r = np.sqrt(x ** 2 + y ** 2 + z ** 2)
# Out:
# Could not find gas gamma, assuming 5./3.

# %%
surface_mask = (r < R_surface) & (r > R_surface * 0.9)
z_mask = (z > -0.1) & (z < 0.1)

# %%
np.sum(surface_mask)
# Out:
# 7002

# %%
plt.scatter(x[surface_mask & z_mask], y[surface_mask & z_mask], s=2)
plt.show()

# %%
plt.hist(T[surface_mask], bins=100)

plt.show()

# %%
P_0 = 1e9
T_0 = 2000

# %%
np.sum(m)
# Out:
# 2.5423552e+25
